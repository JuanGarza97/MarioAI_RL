# %% [markdown]
# # 1. Setup

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py

# %%
#Import the game
import gym_super_mario_bros

#Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace

#Import the simplified controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
#Setup the game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
#Create a flag -> Restart the game or not
restart = True

#Loop through each frame in the game
for step in range(100000):
    if restart:
        #Restart the game
        env.reset()
    #Do random action
    state, reward, restart, info = env.step(env.action_space.sample())
    #Display the game
    env.render()
#Close the game
env.close()

# %%
env.close()

# %% [markdown]
# # 2. Preprocess the Environment

# %%
#Install PyTorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
#Install stable baselines for Reinforced Learning
# !pip install stable-baselines3[extra]

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# # 3. Train The Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=5000000, callback=callback)
# Out:
# Logging to ./logs/PPO_4
# D:\anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 7   |
# |    iterations      | 1   |
# |    time_elapsed    | 67  |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 2             |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 2.8963666e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00636       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 114           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 291           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 3            |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 3.458932e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00293      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 57.6         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 88.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 4            |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0001833248 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0518       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.129        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000836    |
# |    value_loss           | 1.65         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 5            |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 6.733043e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.153        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000458    |
# |    value_loss           | 1.12         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 6             |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.3507903e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0419        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0905        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 0.851         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 7             |
# |    time_elapsed         | 281           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 2.2448017e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0103        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0963        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00021      |
# |    value_loss           | 0.597         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 8            |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 8.849427e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0119      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0845       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 8.09e-08     |
# |    value_loss           | 0.381        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 9             |
# |    time_elapsed         | 361           |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.9989558e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0112       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.095         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000197     |
# |    value_loss           | 0.398         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 10            |
# |    time_elapsed         | 392           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 2.4828478e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0099        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000239     |
# |    value_loss           | 0.304         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 11            |
# |    time_elapsed         | 422           |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 3.7334743e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0031        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000426     |
# |    value_loss           | 0.276         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 12           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 8.916599e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.000158    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.35         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000196    |
# |    value_loss           | 1.84         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 13            |
# |    time_elapsed         | 492           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 2.5687274e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0088       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.082         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000283     |
# |    value_loss           | 0.202         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 14           |
# |    time_elapsed         | 522          |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 3.512425e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00949     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0761       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000327    |
# |    value_loss           | 0.188        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 15            |
# |    time_elapsed         | 557           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 4.8664515e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00377      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0534        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000449     |
# |    value_loss           | 0.152         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 16           |
# |    time_elapsed         | 589          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 2.565165e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0116      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0712       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000218    |
# |    value_loss           | 0.177        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 13            |
# |    iterations           | 17            |
# |    time_elapsed         | 623           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 0.00016445038 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0169        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 169           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000504     |
# |    value_loss           | 404           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 18            |
# |    time_elapsed         | 654           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 2.4474575e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0372        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 26.4          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00017      |
# |    value_loss           | 103           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 19            |
# |    time_elapsed         | 682           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 1.3737124e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.072         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.301         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 7.43e-05      |
# |    value_loss           | 1.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 20            |
# |    time_elapsed         | 711           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 4.8753573e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0774       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.247         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000134      |
# |    value_loss           | 0.829         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 21            |
# |    time_elapsed         | 739           |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 1.4042831e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.119         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.352         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 4.92e-05      |
# |    value_loss           | 0.996         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 22           |
# |    time_elapsed         | 768          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 3.892451e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00435      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.169        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000299    |
# |    value_loss           | 0.646        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 23           |
# |    time_elapsed         | 796          |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 2.686109e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0264       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.159        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000196    |
# |    value_loss           | 0.533        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 24            |
# |    time_elapsed         | 825           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.1109666e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00657       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.158         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000304     |
# |    value_loss           | 0.391         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 25           |
# |    time_elapsed         | 853          |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 4.302361e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0481      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.202        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000372    |
# |    value_loss           | 0.46         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 26            |
# |    time_elapsed         | 883           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 4.2003463e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00103      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.203         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000466     |
# |    value_loss           | 0.338         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 27            |
# |    time_elapsed         | 911           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 4.8746588e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00348       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.144         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -3.24e-05     |
# |    value_loss           | 0.323         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 28           |
# |    time_elapsed         | 940          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 6.209954e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00966      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0516       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000517    |
# |    value_loss           | 0.18         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 29            |
# |    time_elapsed         | 968           |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 1.9037398e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0101        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0749        |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 0.165         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 30           |
# |    time_elapsed         | 997          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 6.734347e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00177     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0978       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000654    |
# |    value_loss           | 0.163        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 31            |
# |    time_elapsed         | 1024          |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 2.2853492e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0105       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0577        |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00023      |
# |    value_loss           | 0.161         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 32            |
# |    time_elapsed         | 1053          |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 4.0387502e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00639       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0637        |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000321     |
# |    value_loss           | 0.168         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 33           |
# |    time_elapsed         | 1080         |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0006053188 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0571       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 127          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000823    |
# |    value_loss           | 285          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 34            |
# |    time_elapsed         | 1109          |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.00022115209 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.113         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 45.6          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -1.27e-05     |
# |    value_loss           | 98.1          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 35            |
# |    time_elapsed         | 1138          |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 2.3184228e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0525        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 5.97          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000252     |
# |    value_loss           | 23.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 36            |
# |    time_elapsed         | 1167          |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00017014903 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0738        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.178         |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 1.31          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 37           |
# |    time_elapsed         | 1199         |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 9.593507e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0538       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000436    |
# |    value_loss           | 1.07         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 38            |
# |    time_elapsed         | 1230          |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 3.5392237e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0159       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.118         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 3.42e-05      |
# |    value_loss           | 0.683         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 39            |
# |    time_elapsed         | 1262          |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 4.1613588e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0992        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -7.55e-05     |
# |    value_loss           | 0.531         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 40            |
# |    time_elapsed         | 1297          |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.7431332e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.106         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.142         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | 0.0001        |
# |    value_loss           | 0.49          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 41            |
# |    time_elapsed         | 1327          |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 1.5720841e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0688       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0963        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -2.13e-05     |
# |    value_loss           | 0.416         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 42           |
# |    time_elapsed         | 1357         |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 3.139733e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0975       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0776       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000267    |
# |    value_loss           | 0.29         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 43            |
# |    time_elapsed         | 1386          |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 4.7681155e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.159        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0798        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 0.255         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 44           |
# |    time_elapsed         | 1417         |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 4.085293e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.0251      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0779       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 0.258        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 45            |
# |    time_elapsed         | 1447          |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 5.7388446e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.105         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0587        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000326     |
# |    value_loss           | 0.157         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 46            |
# |    time_elapsed         | 1483          |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 3.0030147e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.104        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0462        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 0.137         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 47           |
# |    time_elapsed         | 1513         |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 7.649697e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.021       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0484       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000402    |
# |    value_loss           | 0.134        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 48            |
# |    time_elapsed         | 1554          |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.1215412e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.000529     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.26          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 11.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 49           |
# |    time_elapsed         | 1592         |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0010914892 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 141          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000672    |
# |    value_loss           | 434          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 50           |
# |    time_elapsed         | 1627         |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 7.043767e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0661       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000109    |
# |    value_loss           | 1.37         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 51           |
# |    time_elapsed         | 1659         |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0010245742 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 90.8         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000858    |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 52           |
# |    time_elapsed         | 1697         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0006571165 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 95.6         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00126      |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 53           |
# |    time_elapsed         | 1732         |
# |    total_timesteps      | 27136        |
# | train/                  |              |
# |    approx_kl            | 3.606372e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 29.9         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000311    |
# |    value_loss           | 73.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 54            |
# |    time_elapsed         | 1766          |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 1.9212603e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.0136        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 58            |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000405     |
# |    value_loss           | 116           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 55            |
# |    time_elapsed         | 1804          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 0.00032946595 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.465         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0802        |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 4.75          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 56           |
# |    time_elapsed         | 1839         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 8.449587e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.32         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.000665     |
# |    value_loss           | 3.24         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 57          |
# |    time_elapsed         | 1872        |
# |    total_timesteps      | 29184       |
# | train/                  |             |
# |    approx_kl            | 8.16863e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.00602     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.226       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.000121    |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 58            |
# |    time_elapsed         | 1909          |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00012398139 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.036         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.215         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -5.07e-05     |
# |    value_loss           | 1.76          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 59            |
# |    time_elapsed         | 1942          |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 0.00011717086 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.00312       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0795        |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000554     |
# |    value_loss           | 0.977         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 60           |
# |    time_elapsed         | 1979         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 4.751014e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.0306       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0776       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 1.3e-05      |
# |    value_loss           | 0.615        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 61            |
# |    time_elapsed         | 2012          |
# |    total_timesteps      | 31232         |
# | train/                  |               |
# |    approx_kl            | 5.2182237e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.385         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 0.474         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 62            |
# |    time_elapsed         | 2049          |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 5.2800984e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.00682       |
# ...
# |    explained_variance   | 0.844         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 102           |
# |    n_updates            | 26080         |
# |    policy_gradient_loss | -0.000322     |
# |    value_loss           | 201           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2610          |
# |    time_elapsed         | 127693        |
# |    total_timesteps      | 1336320       |
# | train/                  |               |
# |    approx_kl            | 1.2449105e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.202        |
# |    explained_variance   | 0.417         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 622           |
# |    n_updates            | 26090         |
# |    policy_gradient_loss | -0.000116     |
# |    value_loss           | 1.07e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2611          |
# |    time_elapsed         | 127727        |
# |    total_timesteps      | 1336832       |
# | train/                  |               |
# |    approx_kl            | 2.8677052e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.209        |
# |    explained_variance   | 0.706         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 161           |
# |    n_updates            | 26100         |
# |    policy_gradient_loss | -0.000196     |
# |    value_loss           | 330           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2612          |
# |    time_elapsed         | 127758        |
# |    total_timesteps      | 1337344       |
# | train/                  |               |
# |    approx_kl            | 0.00011920126 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.207        |
# |    explained_variance   | 0.313         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 115           |
# |    n_updates            | 26110         |
# |    policy_gradient_loss | -0.00066      |
# |    value_loss           | 247           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2613          |
# |    time_elapsed         | 127792        |
# |    total_timesteps      | 1337856       |
# | train/                  |               |
# |    approx_kl            | 1.0433607e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.214        |
# |    explained_variance   | 0.466         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 391           |
# |    n_updates            | 26120         |
# |    policy_gradient_loss | -4.99e-05     |
# |    value_loss           | 1.03e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2614         |
# |    time_elapsed         | 127826       |
# |    total_timesteps      | 1338368      |
# | train/                  |              |
# |    approx_kl            | 8.130667e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 359          |
# |    n_updates            | 26130        |
# |    policy_gradient_loss | -0.000284    |
# |    value_loss           | 589          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2615         |
# |    time_elapsed         | 127861       |
# |    total_timesteps      | 1338880      |
# | train/                  |              |
# |    approx_kl            | 6.290618e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 105          |
# |    n_updates            | 26140        |
# |    policy_gradient_loss | -0.000168    |
# |    value_loss           | 253          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2616         |
# |    time_elapsed         | 127894       |
# |    total_timesteps      | 1339392      |
# | train/                  |              |
# |    approx_kl            | 8.605188e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 380          |
# |    n_updates            | 26150        |
# |    policy_gradient_loss | -2.87e-05    |
# |    value_loss           | 642          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2617          |
# |    time_elapsed         | 127928        |
# |    total_timesteps      | 1339904       |
# | train/                  |               |
# |    approx_kl            | 0.00012774765 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.224        |
# |    explained_variance   | 0.705         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 156           |
# |    n_updates            | 26160         |
# |    policy_gradient_loss | -0.000785     |
# |    value_loss           | 405           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2618         |
# |    time_elapsed         | 127958       |
# |    total_timesteps      | 1340416      |
# | train/                  |              |
# |    approx_kl            | 0.0007013625 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 213          |
# |    n_updates            | 26170        |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 374          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2619         |
# |    time_elapsed         | 127991       |
# |    total_timesteps      | 1340928      |
# | train/                  |              |
# |    approx_kl            | 0.0003975348 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 105          |
# |    n_updates            | 26180        |
# |    policy_gradient_loss | -0.000513    |
# |    value_loss           | 271          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2620         |
# |    time_elapsed         | 128022       |
# |    total_timesteps      | 1341440      |
# | train/                  |              |
# |    approx_kl            | 7.295166e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 646          |
# |    n_updates            | 26190        |
# |    policy_gradient_loss | 1.93e-05     |
# |    value_loss           | 668          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2621          |
# |    time_elapsed         | 128054        |
# |    total_timesteps      | 1341952       |
# | train/                  |               |
# |    approx_kl            | 5.8136997e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.273        |
# |    explained_variance   | 0.743         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 111           |
# |    n_updates            | 26200         |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 283           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2622          |
# |    time_elapsed         | 128086        |
# |    total_timesteps      | 1342464       |
# | train/                  |               |
# |    approx_kl            | 2.2850581e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.274        |
# |    explained_variance   | 0.547         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 219           |
# |    n_updates            | 26210         |
# |    policy_gradient_loss | 1.88e-05      |
# |    value_loss           | 905           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2623         |
# |    time_elapsed         | 128119       |
# |    total_timesteps      | 1342976      |
# | train/                  |              |
# |    approx_kl            | 4.801259e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 54.9         |
# |    n_updates            | 26220        |
# |    policy_gradient_loss | -0.000235    |
# |    value_loss           | 194          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2624          |
# |    time_elapsed         | 128151        |
# |    total_timesteps      | 1343488       |
# | train/                  |               |
# |    approx_kl            | 0.00013245351 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.264        |
# |    explained_variance   | 0.276         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 233           |
# |    n_updates            | 26230         |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 891           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2625         |
# |    time_elapsed         | 128184       |
# |    total_timesteps      | 1344000      |
# | train/                  |              |
# |    approx_kl            | 0.0009394968 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 71.3         |
# |    n_updates            | 26240        |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 208          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2626          |
# |    time_elapsed         | 128214        |
# |    total_timesteps      | 1344512       |
# | train/                  |               |
# |    approx_kl            | 3.8070837e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.285        |
# |    explained_variance   | 0.656         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 238           |
# |    n_updates            | 26250         |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 341           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2627         |
# |    time_elapsed         | 128247       |
# |    total_timesteps      | 1345024      |
# | train/                  |              |
# |    approx_kl            | 8.148828e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | 0.0207       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 467          |
# |    n_updates            | 26260        |
# |    policy_gradient_loss | -0.000132    |
# |    value_loss           | 1.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 2628         |
# |    time_elapsed         | 128277       |
# |    total_timesteps      | 1345536      |
# | train/                  |              |
# |    approx_kl            | 0.0007357374 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 109          |
# |    n_updates            | 26270        |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 209          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 2629          |
# |    time_elapsed         | 128309        |
# |    total_timesteps      | 1346048       |
# | train/                  |               |
# |    approx_kl            | 2.2368855e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.271        |
# |    explained_variance   | 0.365         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 356           |
# |    n_updates            | 26280         |
# |    policy_gradient_loss | 0.000256      |
# |    value_loss           | 1.09e+03      |
# -------------------------------------------

# %% [markdown]
# # 4. Test

# %%
# Load model
model = PPO.load('./train/best_model_1300000')

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# D:\anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] No se puede cambiar el modo de subproceso después de establecerlo
#   warnings.warn(str(err))
# D:\anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0f88620d5606> in <module>
#       4 while True:
#       5     action, _ = model.predict(state)
# ----> 6     state, reward, done, info = env.step(action)
#       7     env.render()
#
# D:\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# D:\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in step_wait(self)
#      48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
# ---> 50         observations, infos = self.stackedobs.update(observations, dones, infos)
#      51
#      52         return observations, rewards, dones, infos
#
# D:\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\stacked_observations.py in update(self, observations, dones, infos)
#     118         """
#     119         stack_ax_size = observations.shape[self.stack_dimension]
# --> 120         self.stackedobs = np.roll(self.stackedobs, shift=-stack_ax_size, axis=self.stack_dimension)
#     121         for i, done in enumerate(dones):
#     122             if done:
#
# <__array_function__ internals> in roll(*args, **kwargs)
#
# D:\anaconda3\lib\site-packages\numpy\core\numeric.py in roll(a, shift, axis)
#    1207         for indices in itertools.product(*rolls):
#    1208             arr_index, res_index = zip(*indices)
# -> 1209             result[res_index] = a[arr_index]
#    1210
#    1211         return result
#
# KeyboardInterrupt:

# %%
env.close()
